# %% [markdown]
# <a href="https://colab.research.google.com/github/GerardoG2/Medical-Report-Generator/blob/main/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Set Up

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')

# change path
# %cd /content/drive/MyDrive/Medical-Report-Generator/Notebooks
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Medical-Report-Generator/Notebooks

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
FILE_PATH = "../Data/raw_medical_data.csv"

df = pd.read_csv(FILE_PATH)

df.head()
# Out:
#                                                   id   AccessionNumber  \
# 0  pGRDNLZHK1CJMB9DS_aGRDNLD4ATLU63FN8_s1.2.826.0...  GRDNLD4ATLU63FN8
# 1  pGRDN558B6N940827_aGRDNJRM2EFFASEDX_s1.2.826.0...  GRDNJRM2EFFASEDX
# 2  pGRDNS5TAGQ36EJXU_aGRDNAT079HPWLQGQ_s1.2.826.0...  GRDNAT079HPWLQGQ
# 3  pGRDN209D4EU5I2C2_aGRDNM9VVCI1D9171_s1.2.826.0...  GRDNM9VVCI1D9171
# 4  pGRDN5UYSEA2UG5PD_aGRDN3L6AL6JHT3EF_s1.2.826.0...  GRDN3L6AL6JHT3EF
#
#                                     StudyInstanceUid PatientSex PatientAge  \
# 0  1.2.826.0.1.3680043.8.498.98869902613028373370...          M       007Y
# 1  1.2.826.0.1.3680043.8.498.82596686537958139226...          M       057Y
# 2  1.2.826.0.1.3680043.8.498.45885543378002630863...          F       061Y
# 3  1.2.826.0.1.3680043.8.498.66274883271641231571...          M       007M
# 4  1.2.826.0.1.3680043.8.498.79638437312984318878...          F       036Y
#
#    StudyDate StudyDescription                             Indication  \
# 0   20100722      DG CHEST 2V                           Cough, fever
# 1   20160114      DG CHEST 2V  Productive cough for 1 month. Smoker.
# 2   20190327      DG CHEST 2V               Midsternal pain 2 hours.
# 3   20160821      DG CHEST 2V                    Tachypnea, wheezing
# 4   20140727      DG CHEST 2V        Cough and chest pain for 3 days
#
#                                     Comparison  \
# 0                                          NaN
# 1                                          NaN
# 2  Comparison with prior exam from 04/10/2015.
# 3                                          NaN
# 4                                        None.
#
#                                             Findings  \
# 0  No active infiltrate or effusion is seen. Only...
# 1  Heart size is normal. There is no pleural effu...
# 2  Lungs are adequately inflated without focal ai...
# 3  Upper normal heart size. Normal mediastinal co...
# 4  The heart and pulmonary vascularity are within...
#
#                                           Impression
# 0       No pneumonia. Mild peribronchial thickening.
# 1  1. No acute cardiopulmonary abnormalities. 2. ...
# 2                 No active cardiopulmonary disease.
# 3                            No acute abnormalities.
# 4                        No acute abnormality noted.

# %%
df.shape
# Out:
# (140000, 11)

# %%
df.dtypes
# Out:
# id                  object
# AccessionNumber     object
# StudyInstanceUid    object
# PatientSex          object
# PatientAge          object
# StudyDate            int64
# StudyDescription    object
# Indication          object
# Comparison          object
# Findings            object
# Impression          object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                     0
# AccessionNumber        0
# StudyInstanceUid       0
# PatientSex             3
# PatientAge          7012
# StudyDate              0
# StudyDescription       1
# Indication            37
# Comparison          9825
# Findings               0
# Impression             0
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
# Column names
COL_INDICATION   = "Indication"
COL_COMPARISON   = "Comparison"
COL_FINDINGS     = "Findings"
COL_STUDY_DESC   = "StudyDescription"
COL_TARGET       = "Impression"

# Fill missing values in Indication, Comparison, Study_Description

df[COL_INDICATION] = df[COL_INDICATION].fillna("None.")
df[COL_COMPARISON] = df[COL_COMPARISON].fillna("None.")
df[COL_STUDY_DESC] = df[COL_STUDY_DESC].fillna("None.")


print("Missing values after cleaning:")
print(df.isnull().sum())

df.head(10)
# Out:
# Missing values after cleaning:
# id                     0
# AccessionNumber        0
# StudyInstanceUid       0
# PatientSex             3
# PatientAge          7012
# StudyDate              0
# StudyDescription       0
# Indication             0
# Comparison             0
# Findings               0
# Impression             0
# dtype: int64
#                                                   id   AccessionNumber  \
# 0  pGRDNLZHK1CJMB9DS_aGRDNLD4ATLU63FN8_s1.2.826.0...  GRDNLD4ATLU63FN8
# 1  pGRDN558B6N940827_aGRDNJRM2EFFASEDX_s1.2.826.0...  GRDNJRM2EFFASEDX
# 2  pGRDNS5TAGQ36EJXU_aGRDNAT079HPWLQGQ_s1.2.826.0...  GRDNAT079HPWLQGQ
# 3  pGRDN209D4EU5I2C2_aGRDNM9VVCI1D9171_s1.2.826.0...  GRDNM9VVCI1D9171
# 4  pGRDN5UYSEA2UG5PD_aGRDN3L6AL6JHT3EF_s1.2.826.0...  GRDN3L6AL6JHT3EF
# 5  pGRDNELNQSW483H3Y_aGRDNKS32FO0MWO54_s1.2.826.0...  GRDNKS32FO0MWO54
# 6  pGRDNJYHWIBF0I8R1_aGRDNJCNS2WXKC51E_s1.2.826.0...  GRDNJCNS2WXKC51E
# 7  pGRDNS282KQMLYD8W_aGRDNPY687L2R5E4Y_s1.2.826.0...  GRDNPY687L2R5E4Y
# 8  pGRDNUUKG19JGCSMQ_aGRDN53TO1ISBNW1D_s1.2.826.0...  GRDN53TO1ISBNW1D
# 9  pGRDNLXEHE3IZRH6C_aGRDNRDHGJ75WD20Y_s1.2.826.0...  GRDNRDHGJ75WD20Y
#
#                                     StudyInstanceUid PatientSex PatientAge  \
# 0  1.2.826.0.1.3680043.8.498.98869902613028373370...          M       007Y
# 1  1.2.826.0.1.3680043.8.498.82596686537958139226...          M       057Y
# 2  1.2.826.0.1.3680043.8.498.45885543378002630863...          F       061Y
# 3  1.2.826.0.1.3680043.8.498.66274883271641231571...          M       007M
# 4  1.2.826.0.1.3680043.8.498.79638437312984318878...          F       036Y
# 5  1.2.826.0.1.3680043.8.498.94602140310111155555...          F       029Y
# 6  1.2.826.0.1.3680043.8.498.90360658723187858198...          M       050Y
# 7  1.2.826.0.1.3680043.8.498.45377335160322619016...          M       073Y
# 8  1.2.826.0.1.3680043.8.498.75128803173103393749...          M       030Y
# 9  1.2.826.0.1.3680043.8.498.31561878357566563614...          M       035Y
#
#    StudyDate  StudyDescription  \
# 0   20100722       DG CHEST 2V
# 1   20160114       DG CHEST 2V
# 2   20190327       DG CHEST 2V
# 3   20160821       DG CHEST 2V
# 4   20140727       DG CHEST 2V
# 5   20080309       DG CHEST 2V
# 6   20200725  DG CHEST 1V PORT
# 7   20231222              [ID]
# 8   20160126       DG CHEST 2V
# 9   20141212       DG CHEST 2V
#
#                                           Indication  \
# 0                                       Cough, fever
# 1              Productive cough for 1 month. Smoker.
# 2                           Midsternal pain 2 hours.
# 3                                Tachypnea, wheezing
# 4                    Cough and chest pain for 3 days
# 5  28 year-old female, lymphoma currently on chem...
# 6                                 Preoperative exam.
# 7  Fall. Syncope; fall; hx of open heart sx; pt s...
# 8                        Chest pain, short of breath
# 9                                   Chest tightness.
#
#                                         Comparison  \
# 0                                            None.
# 1                                            None.
# 2      Comparison with prior exam from 04/10/2015.
# 3                                            None.
# 4                                            None.
# 5                            Comparison: 03/10/06.
# 6                                      02/05/2018.
# 7                 Comparisons to January 16, 2018.
# 8                             Comparison: 5/9/2009
# 9  None available at time of study interpretation.
#
#                                             Findings  \
# 0  No active infiltrate or effusion is seen. Only...
# 1  Heart size is normal. There is no pleural effu...
# 2  Lungs are adequately inflated without focal ai...
# 3  Upper normal heart size. Normal mediastinal co...
# 4  The heart and pulmonary vascularity are within...
# 5  Low lung volumes without acute consolidation, ...
# 6  The heart size and mediastinal contours are wi...
# 7  Worsened multifocal bilateral mid lower lung p...
# 8  Normal mediastinum and cardiac silhouette. Rig...
# 9  The cardiomediastinal silhouette is unremarkab...
#
#                                           Impression
# 0       No pneumonia. Mild peribronchial thickening.
# 1  1. No acute cardiopulmonary abnormalities. 2. ...
# 2                 No active cardiopulmonary disease.
# 3                            No acute abnormalities.
# 4                        No acute abnormality noted.
# 5  1. Low volume exam without acute airspace proc...
# 6                                 No active disease.
# 7  Worsening mid and lower lung predominant airsp...
# 8  Chronic atelectasis versus less likely infecti...
# 9                  No acute cardiopulmonary process.

# %%
# Create source and target columns

def build_source_row(row):
    return " ".join([
        f"[INDICATION] {row[COL_INDICATION]}",
        f"[COMPARISON] {row[COL_COMPARISON]}",
        f"[FINDINGS] {row[COL_FINDINGS]}",
    ])

df["source_text"] = df.apply(build_source_row, axis=1)
df["target_text"] = df[COL_TARGET].astype(str)

df
# Out:
#                                                        id   AccessionNumber  \
# 0       pGRDNLZHK1CJMB9DS_aGRDNLD4ATLU63FN8_s1.2.826.0...  GRDNLD4ATLU63FN8
# 1       pGRDN558B6N940827_aGRDNJRM2EFFASEDX_s1.2.826.0...  GRDNJRM2EFFASEDX
# 2       pGRDNS5TAGQ36EJXU_aGRDNAT079HPWLQGQ_s1.2.826.0...  GRDNAT079HPWLQGQ
# 3       pGRDN209D4EU5I2C2_aGRDNM9VVCI1D9171_s1.2.826.0...  GRDNM9VVCI1D9171
# 4       pGRDN5UYSEA2UG5PD_aGRDN3L6AL6JHT3EF_s1.2.826.0...  GRDN3L6AL6JHT3EF
# ...                                                   ...               ...
# 139995  pGRDNXBTSJF476I2N_aGRDNOXAQ28KRW4GZ_s1.2.826.0...  GRDNOXAQ28KRW4GZ
# 139996  pGRDN1GWNQ8GR6XX8_aGRDNNUZ50U648VR6_s1.2.826.0...  GRDNNUZ50U648VR6
# 139997  pGRDN518BHGVULJRC_aGRDN6QZEQ1QT8YF9_s1.2.826.0...  GRDN6QZEQ1QT8YF9
# 139998  pGRDNMUS16DV29OCF_aGRDN0S46J1DRAHXG_s1.2.826.0...  GRDN0S46J1DRAHXG
# 139999  pGRDNNCEMYHMF9CU4_aGRDNZ1SNG53BCLG1_s1.2.826.0...  GRDNZ1SNG53BCLG1
#
#                                          StudyInstanceUid PatientSex  \
# 0       1.2.826.0.1.3680043.8.498.98869902613028373370...          M
# 1       1.2.826.0.1.3680043.8.498.82596686537958139226...          M
# 2       1.2.826.0.1.3680043.8.498.45885543378002630863...          F
# 3       1.2.826.0.1.3680043.8.498.66274883271641231571...          M
# 4       1.2.826.0.1.3680043.8.498.79638437312984318878...          F
# ...                                                   ...        ...
# 139995  1.2.826.0.1.3680043.8.498.24718307818624585717...          F
# 139996  1.2.826.0.1.3680043.8.498.84987404802016573120...          F
# 139997  1.2.826.0.1.3680043.8.498.43036822772610310582...          M
# 139998  1.2.826.0.1.3680043.8.498.26144389355329300559...          F
# 139999  1.2.826.0.1.3680043.8.498.61405159582496165300...          F
#
#        PatientAge  StudyDate              StudyDescription  \
# 0            007Y   20100722                   DG CHEST 2V
# 1            057Y   20160114                   DG CHEST 2V
# 2            061Y   20190327                   DG CHEST 2V
# 3            007M   20160821                   DG CHEST 2V
# 4            036Y   20140727                   DG CHEST 2V
# ...           ...        ...                           ...
# 139995       025Y   20221015                   DG CHEST 2V
# 139996        NaN   20111024                  Chest 1 View
# 139997       000D   20160729   DG CHEST PORT W/ABD NEONATE
# 139998       017Y   20150817  DG ABDOMEN ACUTE W/ 1V CHEST
# 139999       065Y   20190113                   DG CHEST 2V
#
#                                            Indication  \
# 0                                        Cough, fever
# 1               Productive cough for 1 month. Smoker.
# 2                            Midsternal pain 2 hours.
# 3                                 Tachypnea, wheezing
# 4                     Cough and chest pain for 3 days
# ...                                               ...
# 139995                                   Cough, fever
# 139996                                            Pna
# 139997            Status post endotracheal intubation
# 139998                        Diffuse abdominal pain.
# 139999  Motor vehicle collision today, mid chest pain
#
#                                          Comparison  \
# 0                                             None.
# 1                                             None.
# 2       Comparison with prior exam from 04/10/2015.
# 3                                             None.
# 4                                             None.
# ...                                             ...
# 139995                                        None.
# 139996                                        None.
# 139997                                        None.
# 139998                                        None.
# 139999                                        None.
#
#                                                  Findings  \
# 0       No active infiltrate or effusion is seen. Only...
# 1       Heart size is normal. There is no pleural effu...
# 2       Lungs are adequately inflated without focal ai...
# 3       Upper normal heart size. Normal mediastinal co...
# 4       The heart and pulmonary vascularity are within...
# ...                                                   ...
# 139995  The heart size and mediastinal contours are wi...
# 139996  EKG leads project over the patient's chest. Th...
# 139997  Cardiac shadow is within normal limits. The lu...
# 139998  There is no evidence of dilated bowel loops or...
# 139999  There is linear atelectasis or scarring at the...
#
#                                                Impression  \
# 0            No pneumonia. Mild peribronchial thickening.
# 1       1. No acute cardiopulmonary abnormalities. 2. ...
# 2                      No active cardiopulmonary disease.
# 3                                 No acute abnormalities.
# 4                             No acute abnormality noted.
# ...                                                   ...
# 139995                 No acute abnormality of the lungs.
# 139996  Probable vascular congestion and bilateral inf...
# 139997  Endotracheal tube at the level of the carina d...
# 139998  Negative abdominal radiographs. No acute cardi...
# 139999  Linear atelectasis or scarring at the left lun...
#
#                                               source_text  \
# 0       [INDICATION] Cough, fever [COMPARISON] None. [...
# 1       [INDICATION] Productive cough for 1 month. Smo...
# 2       [INDICATION] Midsternal pain 2 hours. [COMPARI...
# 3       [INDICATION] Tachypnea, wheezing [COMPARISON] ...
# 4       [INDICATION] Cough and chest pain for 3 days [...
# ...                                                   ...
# 139995  [INDICATION] Cough, fever [COMPARISON] None. [...
# 139996  [INDICATION] Pna [COMPARISON] None. [FINDINGS]...
# 139997  [INDICATION] Status post endotracheal intubati...
# 139998  [INDICATION] Diffuse abdominal pain. [COMPARIS...
# 139999  [INDICATION] Motor vehicle collision today, mi...
#
#                                               target_text
# 0            No pneumonia. Mild peribronchial thickening.
# 1       1. No acute cardiopulmonary abnormalities. 2. ...
# 2                      No active cardiopulmonary disease.
# 3                                 No acute abnormalities.
# 4                             No acute abnormality noted.
# ...                                                   ...
# 139995                 No acute abnormality of the lungs.
# 139996  Probable vascular congestion and bilateral inf...
# 139997  Endotracheal tube at the level of the carina d...
# 139998  Negative abdominal radiographs. No acute cardi...
# 139999  Linear atelectasis or scarring at the left lun...
#
# [140000 rows x 13 columns]
# Warning: total number of rows (140000) exceeds max_rows (20000). Limiting to first (20000) rows.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['StudyDate'].plot(kind='hist', bins=20, title='StudyDate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('PatientSex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='index', y='StudyDate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('PatientSex')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='PatientSex', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['StudyDate']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'StudyDate'}, axis=1)
#               .sort_values('StudyDate', ascending=True))
#   xs = counted['StudyDate']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('StudyDate', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('PatientSex')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='PatientSex', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('StudyDate')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['StudyDate'].plot(kind='line', figsize=(8, 4), title='StudyDate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_8['PatientSex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_8, x='index', y='PatientSex', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['PatientSex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='StudyDate', y='PatientSex', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# check token length of source text column
df["source_text"].apply(lambda x: len(x.split())).describe()
# Out:
# count    140000.000000
# mean         43.779964
# std          18.486596
# min           9.000000
# 25%          30.000000
# 50%          40.000000
# 75%          52.000000
# max         311.000000
# Name: source_text, dtype: float64

# %%
# check token length of target text column
df["target_text"].apply(lambda x: len(x.split())).describe()
# Out:
# count    140000.000000
# mean         11.637150
# std          11.417352
# min           1.000000
# 25%           4.000000
# 50%           7.000000
# 75%          15.000000
# max         164.000000
# Name: target_text, dtype: float64

# %% [markdown]
# Save Clean Data Split

# %%
# Split into Train, Val, Test sets and Save CSV
from pathlib import Path

SAVE_DIR = Path("../Data")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

N = len(df)
rng = np.random.default_rng(42)
perm = rng.permutation(N) # shuffle data

p_train, p_val, p_test = 0.80, 0.10, 0.10

n_train = int(round(N * p_train))
n_val   = int(round(N * p_val))
n_test  = N - n_train - n_val

train_idx = perm[:n_train]
val_idx   = perm[n_train:n_train + n_val]
test_idx  = perm[n_train + n_val:]

train_df = df.iloc[train_idx][["source_text", "target_text"]].reset_index(drop=True)
val_df   = df.iloc[val_idx][["source_text", "target_text"]].reset_index(drop=True)
test_df  = df.iloc[test_idx][["source_text", "target_text"]].reset_index(drop=True)

train_path = SAVE_DIR / "train.csv"
val_path   = SAVE_DIR / "val.csv"
test_path  = SAVE_DIR / "test.csv"

train_df.to_csv(train_path, index=False)
val_df.to_csv(val_path, index=False)
test_df.to_csv(test_path, index=False)

print(f"Saved: {train_path} ({len(train_df)})")
print(f"Saved: {val_path}   ({len(val_df)})")
print(f"Saved: {test_path}  ({len(test_df)})")
# Out:
# Saved: ../Data/train.csv (112000)
# Saved: ../Data/val.csv   (14000)
# Saved: ../Data/test.csv  (14000)

# %%
train_df
# Out:
#                                               source_text  \
# 0       [INDICATION] Followup pneumonia. Cough. [COMPA...
# 1       [INDICATION] Check tub placement [COMPARISON] ...
# 2       [INDICATION] Lung lesion [COMPARISON] Comparis...
# 3       [INDICATION] Left-sided chest pain and shortne...
# 4       [INDICATION] Chest pain [COMPARISON] None. [FI...
# ...                                                   ...
# 111995  [INDICATION] Fever and shortness of breath. Co...
# 111996  [INDICATION] Chest pain and shortness of breat...
# 111997  [INDICATION] Chest pain [COMPARISON] None. [FI...
# 111998  [INDICATION] Dizziness, syncope, cough common ...
# 111999  [INDICATION] Cough and congestion for almost 1...
#
#                                               target_text
# 0       1. Bilateral lower lobe airspace disease most ...
# 1       Nasogastric tube tip in the distal esophagus. ...
# 2                                              No change.
# 3                                      No active disease.
# 4       No radiographic evidence of acute cardiopulmon...
# ...                                                   ...
# 111995                         No edema or consolidation.
# 111996  Cardiac enlargement with vascular congestion. ...
# 111997                  No acute cardiopulmonary process.
# 111998        There is no active cardiopulmonary disease.
# 111999                                    Negative chest.
#
# [112000 rows x 2 columns]

# %%
test_df
# Out:
#                                              source_text  \
# 0      [INDICATION] Preoperative chest x-ray for hyst...
# 1      [INDICATION] Heart palpitations. [COMPARISON] ...
# 2      [INDICATION] Cough [COMPARISON] Comparison is ...
# 3      [INDICATION] Prior ultrasound with hydronephro...
# 4      [INDICATION] Chest pain [COMPARISON] Compariso...
# ...                                                  ...
# 13995  [INDICATION] Cough and right-sided rib pain [C...
# 13996  [INDICATION] Chest pain beginning at 5 p.m. to...
# 13997  [INDICATION] Fever. Chills. [COMPARISON] Compa...
# 13998  [INDICATION] Atrial fibrillation. Decreased ox...
# 13999  [INDICATION] Cough, congestion, hypertension [...
#
#                                             target_text
# 0                 No evidence for active chest disease.
# 1                     No acute cardiopulmonary process.
# 2                     No acute cardiopulmonary disease.
# 3         No definite vesicoureteral reflux identified.
# 4                         Left base linear atelectasis.
# ...                                                 ...
# 13995                No active cardiopulmonary disease.
# 13996                                   Negative chest.
# 13997                          Normal and stable chest.
# 13998  No acute cardiopulmonary disease. Possible COPD.
# 13999                           No active lung disease.
#
# [14000 rows x 2 columns]

# %%
val_df
# Out:
#                                              source_text  \
# 0      [INDICATION] History of chronic coughing. [COM...
# 1      [INDICATION] Status post shortness of breath. ...
# 2      [INDICATION] Shortness of breath for several d...
# 3      [INDICATION] Unstable premature newborn; 35 we...
# 4      [INDICATION] Low BP, patient very lethargic. [...
# ...                                                  ...
# 13995  [INDICATION] Hypoxia and lung crackles. [COMPA...
# 13996  [INDICATION] Evaluate for foreign body [COMPAR...
# 13997  [INDICATION] Dyspnea and posterior right chest...
# 13998  [INDICATION] Cough and congestion [COMPARISON]...
# 13999  [INDICATION] Chest tightness and shortness of ...
#
#                                              target_text
# 0      Question minimal hyperinflation. Heart size is...
# 1      Borderline cardiomegaly with diffuse interstit...
# 2             Chronic changes without acute abnormality.
# 3                                                   RDS.
# 4      Cardiomegaly with mild congestive heart failur...
# ...                                                  ...
# 13995  Bronchitic airway thickening. No collapse or c...
# 13996                                     Negative exam.
# 13997    No active cardiopulmonary process demonstrated.
# 13998  Bibasilar infiltrates left considerable greate...
# 13999                 No active cardiopulmonary disease.
#
# [14000 rows x 2 columns]
